# %%
import pandas as pd
from rdkit import Chem
from rdkit.DataStructs.cDataStructs import TanimotoSimilarity

# %%
tensero_noise_0_1 = pd.read_excel('../Data/Molecules_generated_tensor_scaling_0_1.xlsx')

# %%
tensero_noise_0_1 = tensero_noise_0_1['SMILES_From_Tensor_rotation']

# %%
tensero_noise_0_1_new_smils = []
for smiles in tensero_noise_0_1:
    canon = Chem.MolToSmiles(Chem.MolFromSmiles(smiles), canonical=True, isomericSmiles=False)
    tensero_noise_0_1_new_smils.append(canon)

tensero_noise_0_1_new_smils = pd.DataFrame(data=tensero_noise_0_1_new_smils, columns=['SMILES'])
tensero_noise_0_1_new_smils = tensero_noise_0_1_new_smils.drop_duplicates(subset=['SMILES'])
#list(set(tensero_noise_0_1_new_smils))
tensero_noise_0_1_new_smils.head()
# Out:
#                         SMILES
# 0        CCCOCc1c[nH]c2ccccc12
# 2   CCC(C)CCOCc1c[nH]c2ccccc12
# 3  CC(C)c1nccn1C1C=CNc2ccccc21
# 4    CCCOCCc1ccccc1N=[N+]=[N-]
# 5     CC(C)COCc1c[nH]c2ccccc12

# %%
tensero_noise_0_2 = pd.read_excel('../Data/Molecules_generated_tensor_scaling_0_2.xlsx')

# %%
tensero_noise_0_2 = tensero_noise_0_2['SMILES_From_Tensor_rotation']

# %%
tensero_noise_0_2_new_smils = []
for smiles in tensero_noise_0_2:
    canon = Chem.MolToSmiles(Chem.MolFromSmiles(smiles), canonical=True, isomericSmiles=False)
    tensero_noise_0_2_new_smils.append(canon)
    
tensero_noise_0_2_new_smils = pd.DataFrame(data=tensero_noise_0_2_new_smils, columns=['SMILES'])
tensero_noise_0_2_new_smils = tensero_noise_0_2_new_smils.drop_duplicates(subset=['SMILES'])
#list(set(tensero_noise_0_1_new_smils))
tensero_noise_0_2_new_smils.head()
# Out:
#                               SMILES
# 0        C1=CN(Cc2c[nH]c3ccccc23)CN1
# 1  C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12
# 2             C=C1C=C(C)NCC2C=CC2CN1
# 3      C=C1CN(Cc2c[nH]c3ccccc23)C=N1
# 4            Cc1ncc2n1CC1=CC=CC1CNC2

# %%
generated_structures = pd.read_excel('../Data/Proposed_structures_with_AI_indole_tanimoto_similarity_.xlsx')

# %%
generated_structures.head()
# Out:
#    Unnamed: 0                         new_SMILES  CID PUBCHEM_SMILES  \
# 0           0        C1=CN(Cc2c[nH]c3ccccc23)CN1    0              0
# 1           1  C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12    0              0
# 2           2             C=C1C=C(C)NCC2C=CC2CN1    0              0
# 3           3      C=C1CN(Cc2c[nH]c3ccccc23)C=N1    0              0
# 4           4            Cc1ncc2n1CC1=CC=CC1CNC2    0              0
#
#    CC(C)OCC1=CNC2=CC=CC=C21  O=C(C)OCC1=CN(C(C)=O)C2=CC=CC=C21  \
# 0                  0.446228                           0.370541
# 1                  0.170796                           0.270079
# 2                  0.074313                           0.083995
# 3                  0.422680                           0.366703
# 4                  0.160750                           0.227615
#
#    [N-]=[N+]=NCC1=CC=C(CN2N=NC(COCC3=CNC4=C3C=CC=C4)=C2)C=C1  \
# 0                                           0.380471
# 1                                           0.267843
# 2                                           0.104444
# 3                                           0.379127
# 4                                           0.242574
#
#    CCCCOCC1=CNC2=CC=CC=C21  CCC1=NC=CN1CC2=CNC3=CC=CC=C32  \
# 0                 0.448166                       0.365217
# 1                 0.174912                       0.286802
# 2                 0.080386                       0.097964
# 3                 0.426686                       0.367803
# 4                 0.161923                       0.250000
#
#    CCOCC1=CNC2=CC=CC=C21  ...  \
# 0               0.452459  ...
# 1               0.163701  ...
# 2               0.072607  ...
# 3               0.427928  ...
# 4               0.153923  ...
#
#    C12=CC=CC=C1NC=C2COCC3=CN(CCCCCCCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3  \
# 0                                           0.365042
# 1                                           0.263073
# 2                                           0.090909
# 3                                           0.375283
# 4                                           0.229706
#
#    C12=CC=CC=C1NC=C2COCC3=CN(CCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3  \
# 0                                           0.368990
# 1                                           0.252809
# 2                                           0.089264
# 3                                           0.372862
# 4                                           0.218777
#
#    [N-]=[N+]=NCC1=CC(CN=[N+]=[N-])=CC(CN2N=NC(COCC3=CNC4=C3C=CC=C4)=C2)=C1  \
# 0                                           0.372698
# 1                                           0.269925
# 2                                           0.102674
# 3                                           0.373196
# 4                                           0.244355
#
#    C12=CC=CC=C1C(CN3C(C=CC=C4)=C4N=C3)=CN2  \
# 0                                 0.354340
# 1                                 0.249800
# 2                                 0.090580
# 3                                 0.361991
# 4                                 0.235808
#
#    O=C(C=C1)NC(N1CC2=CNC3=CC=CC=C32)=S  CC(C)CCOCC1=CNC2=CC=CC=C21  \
# 0                             0.353900                    0.448657
# 1                             0.239249                    0.179736
# 2                             0.100950                    0.086124
# 3                             0.346491                    0.423188
# 4                             0.249132                    0.167319
#
#    O=C1C2=C(C=CC=C2)C(N1CC3=CN(C(C)=C)C4=CC=CC=C43)=O  \
# 0                                           0.440589
# 1                                           0.303273
# 2                                           0.102041
# 3                                           0.430708
# 4                                           0.267129
#
#    S=C1N(CC2=CNC3=CC=CC=C32)C(C=CC=C4)=C4S1  \
# 0                                  0.324612
# 1                                  0.287977
# 2                                  0.100195
# 3                                  0.332093
# 4                                  0.265794
#
#    CN(C)CC1=CN(C2=C1C=CC=C2)CC3=CNC4=CC=CC=C43  \
# 0                                     0.500000
# 1                                     0.265941
# 2                                     0.096045
# 3                                     0.486550
# 4                                     0.241206
#
#    C12=CC=CC=C1NC=C2COCC3=CN(CCCCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3
# 0                                           0.365591
# 1                                           0.262097
# 2                                           0.090144
# 3                                           0.375854
# 4                                           0.229636
#
# [5 rows x 48 columns]

# %%
generated_structures = generated_structures['new_SMILES']

# %%
generated_structures[:3]
# Out:
# 0          C1=CN(Cc2c[nH]c3ccccc23)CN1
# 1    C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12
# 2               C=C1C=C(C)NCC2C=CC2CN1
# Name: new_SMILES, dtype: object

# %%
df = pd.DataFrame(data=list(generated_structures), columns=['Generated_SMILES'])
df['Noise_0.1'] = 0
df['Noise_0.2'] = 0
df['Related_SMILES_from_raw_generation'] = 0
df['Tanimoto_sim_structures_from_raw_data'] = 0

# %%
for r, m in enumerate(df['Generated_SMILES']):
    #fingerprint_ = Chem.RDKFingerprint(Chem.MolFromSmiles(m))
    for i, element in enumerate(tensero_noise_0_1_new_smils['SMILES']):
        #fingerprint_gen_str = Chem.RDKFingerprint(Chem.MolFromSmiles(element))
        #sim = TanimotoSimilarity(fingerprint_, fingerprint_gen_str)
        if element == m:
            df['Noise_0.1'][r] = 1
            df['Related_SMILES_from_raw_generation'][r] = element
            #df['Tanimoto_sim'][r] = sim
        else:
            pass
    for i, element in enumerate(tensero_noise_0_2_new_smils['SMILES']):
        #fingerprint_gen_str = Chem.RDKFingerprint(Chem.MolFromSmiles(element))
        #sim = TanimotoSimilarity(fingerprint_, fingerprint_gen_str)
        if element == m:
            df['Noise_0.2'][r] = 1
            df['Related_SMILES_from_raw_generation'][r] = element
            #df['Tanimoto_sim'][r] = sim
        else:
            pass
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_27804\3191894201.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Noise_0.2'][r] = 1
# C:\Users\aleks\AppData\Local\Temp\ipykernel_27804\3191894201.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Related_SMILES_from_raw_generation'][r] = element
# C:\Users\aleks\AppData\Local\Temp\ipykernel_27804\3191894201.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Noise_0.1'][r] = 1

# %%
df.head()
# Out:
#                     Generated_SMILES  Noise_0.1  Noise_0.2  \
# 0        C1=CN(Cc2c[nH]c3ccccc23)CN1          0          1
# 1  C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12          0          1
# 2             C=C1C=C(C)NCC2C=CC2CN1          0          1
# 3      C=C1CN(Cc2c[nH]c3ccccc23)C=N1          0          1
# 4            Cc1ncc2n1CC1=CC=CC1CNC2          0          1
#
#   Related_SMILES_from_raw_generation  Tanimoto_sim_structures_from_raw_data
# 0        C1=CN(Cc2c[nH]c3ccccc23)CN1                                      0
# 1  C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12                                      0
# 2             C=C1C=C(C)NCC2C=CC2CN1                                      0
# 3      C=C1CN(Cc2c[nH]c3ccccc23)C=N1                                      0
# 4            Cc1ncc2n1CC1=CC=CC1CNC2                                      0

# %%
for i, smile in enumerate(df['Related_SMILES_from_raw_generation']):
    fingerprint_ = Chem.RDKFingerprint(Chem.MolFromSmiles(smile))
    for element in tensero_noise_0_1:
        fingerprint_gen_str = Chem.RDKFingerprint(Chem.MolFromSmiles(element))
        sim = TanimotoSimilarity(fingerprint_, fingerprint_gen_str)
        if sim > 0.98:
            df['Tanimoto_sim_structures_from_raw_data'][i] = element
        else:
            pass
    for element in tensero_noise_0_2:
        fingerprint_gen_str = Chem.RDKFingerprint(Chem.MolFromSmiles(element))
        sim = TanimotoSimilarity(fingerprint_, fingerprint_gen_str)
        if sim > 0.98:
            df['Tanimoto_sim_structures_from_raw_data'][i] = element
        else:
            pass
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_27804\2574084956.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tanimoto_sim_structures_from_raw_data'][i] = element

# %%
df.head()
# Out:
#                     Generated_SMILES  Noise_0.1  Noise_0.2  \
# 0        C1=CN(Cc2c[nH]c3ccccc23)CN1          0          1
# 1  C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12          0          1
# 2             C=C1C=C(C)NCC2C=CC2CN1          0          1
# 3      C=C1CN(Cc2c[nH]c3ccccc23)C=N1          0          1
# 4            Cc1ncc2n1CC1=CC=CC1CNC2          0          1
#
#   Related_SMILES_from_raw_generation  Tanimoto_sim_structures_from_raw_data
# 0        C1=CN(Cc2c[nH]c3ccccc23)CN1     C1[NH1]C=CN1CC2=C[NH1]C3=CC=CC=C32
# 1  C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12  CC1(CN2C=C(N=C2CC)C[NH1]C3=C)C=CC=C31
# 2             C=C1C=C(C)NCC2C=CC2CN1         C12C(CNC(C)=CC([NH1]C1)=C)C=C2
# 3      C=C1CN(Cc2c[nH]c3ccccc23)C=N1     C=C1CN(C=N1)CC2=C[NH1]C3=CC=CC=C32
# 4            Cc1ncc2n1CC1=CC=CC1CNC2      C12C(CN3C(C)=NC=C3C[NH1]C1)=CC=C2

# %%
df.to_excel('../Data/Assignment of generation mode.xlsx')
