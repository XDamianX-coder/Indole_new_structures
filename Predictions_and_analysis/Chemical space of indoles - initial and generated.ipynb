# %%
import pandas as pd
import numpy as np

# %%
File_to_work_with = '../Data/Proposed_structures_with_AI_indole_tanimoto_similarity_.xlsx'

# %%
initial = pd.read_excel(File_to_work_with)

# %%
initial.head()
# Out:
#    Unnamed: 0                         new_SMILES  CID PUBCHEM_SMILES  \
# 0           0        C1=CN(Cc2c[nH]c3ccccc23)CN1    0              0
# 1           1  C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12    0              0
# 2           2             C=C1C=C(C)NCC2C=CC2CN1    0              0
# 3           3      C=C1CN(Cc2c[nH]c3ccccc23)C=N1    0              0
# 4           4            Cc1ncc2n1CC1=CC=CC1CNC2    0              0
#
#    CC(C)OCC1=CNC2=CC=CC=C21  O=C(C)OCC1=CN(C(C)=O)C2=CC=CC=C21  \
# 0                  0.446228                           0.370541
# 1                  0.170796                           0.270079
# 2                  0.074313                           0.083995
# 3                  0.422680                           0.366703
# 4                  0.160750                           0.227615
#
#    [N-]=[N+]=NCC1=CC=C(CN2N=NC(COCC3=CNC4=C3C=CC=C4)=C2)C=C1  \
# 0                                           0.380471
# 1                                           0.267843
# 2                                           0.104444
# 3                                           0.379127
# 4                                           0.242574
#
#    CCCCOCC1=CNC2=CC=CC=C21  CCC1=NC=CN1CC2=CNC3=CC=CC=C32  \
# 0                 0.448166                       0.365217
# 1                 0.174912                       0.286802
# 2                 0.080386                       0.097964
# 3                 0.426686                       0.367803
# 4                 0.161923                       0.250000
#
#    CCOCC1=CNC2=CC=CC=C21  ...  \
# 0               0.452459  ...
# 1               0.163701  ...
# 2               0.072607  ...
# 3               0.427928  ...
# 4               0.153923  ...
#
#    C12=CC=CC=C1NC=C2COCC3=CN(CCCCCCCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3  \
# 0                                           0.365042
# 1                                           0.263073
# 2                                           0.090909
# 3                                           0.375283
# 4                                           0.229706
#
#    C12=CC=CC=C1NC=C2COCC3=CN(CCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3  \
# 0                                           0.368990
# 1                                           0.252809
# 2                                           0.089264
# 3                                           0.372862
# 4                                           0.218777
#
#    [N-]=[N+]=NCC1=CC(CN=[N+]=[N-])=CC(CN2N=NC(COCC3=CNC4=C3C=CC=C4)=C2)=C1  \
# 0                                           0.372698
# 1                                           0.269925
# 2                                           0.102674
# 3                                           0.373196
# 4                                           0.244355
#
#    C12=CC=CC=C1C(CN3C(C=CC=C4)=C4N=C3)=CN2  \
# 0                                 0.354340
# 1                                 0.249800
# 2                                 0.090580
# 3                                 0.361991
# 4                                 0.235808
#
#    O=C(C=C1)NC(N1CC2=CNC3=CC=CC=C32)=S  CC(C)CCOCC1=CNC2=CC=CC=C21  \
# 0                             0.353900                    0.448657
# 1                             0.239249                    0.179736
# 2                             0.100950                    0.086124
# 3                             0.346491                    0.423188
# 4                             0.249132                    0.167319
#
#    O=C1C2=C(C=CC=C2)C(N1CC3=CN(C(C)=C)C4=CC=CC=C43)=O  \
# 0                                           0.440589
# 1                                           0.303273
# 2                                           0.102041
# 3                                           0.430708
# 4                                           0.267129
#
#    S=C1N(CC2=CNC3=CC=CC=C32)C(C=CC=C4)=C4S1  \
# 0                                  0.324612
# 1                                  0.287977
# 2                                  0.100195
# 3                                  0.332093
# 4                                  0.265794
#
#    CN(C)CC1=CN(C2=C1C=CC=C2)CC3=CNC4=CC=CC=C43  \
# 0                                     0.500000
# 1                                     0.265941
# 2                                     0.096045
# 3                                     0.486550
# 4                                     0.241206
#
#    C12=CC=CC=C1NC=C2COCC3=CN(CCCCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3
# 0                                           0.365591
# 1                                           0.262097
# 2                                           0.090144
# 3                                           0.375854
# 4                                           0.229636
#
# [5 rows x 48 columns]

# %%
initial = initial.columns.values.tolist()

# %%
initial
# Out:
# ['Unnamed: 0',
#  'new_SMILES',
#  'CID',
#  'PUBCHEM_SMILES',
#  'CC(C)OCC1=CNC2=CC=CC=C21',
#  'O=C(C)OCC1=CN(C(C)=O)C2=CC=CC=C21',
#  '[N-]=[N+]=NCC1=CC=C(CN2N=NC(COCC3=CNC4=C3C=CC=C4)=C2)C=C1',
#  'CCCCOCC1=CNC2=CC=CC=C21',
#  'CCC1=NC=CN1CC2=CNC3=CC=CC=C32',
#  'CCOCC1=CNC2=CC=CC=C21',
#  'O=C(C(C=CC=C1)=C1C2=O)N2CCCCCCCCN3N=NC(COCC4=CNC5=C4C=CC=C5)=C3',
#  'C12=CC=CC=C1C(CN3C=CN=C3)=CN2',
#  'C12=CC=CC=C1NC=C2COCC3=CN(CCCCCCCCCCCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3',
#  'CCC1=NC(C)=CN1CC2=CNC3=CC=CC=C32',
#  'CC1=NC=CN1CC2=CNC3=CC=CC=C32',
#  'O=C(C(C=CC=C1)=C1C2=O)N2CCCCCCCCCCCCN3N=NC(COCC4=CNC5=C4C=CC=C5)=C3',
#  'O=C(C=C1)N(CC2=CNC3=C2C=CC=C3)C(N1CC4=CNC5=CC=CC=C54)=O',
#  'COCC1=CNC2=CC=CC=C21',
#  'CC(C)C1=NC=CN1CC2=CNC3=CC=CC=C32',
#  'O=C(C)N(C1=C2C=CC=C1)C=C2CN3N=NC(COCC4=CNC5=C4C=CC=C5)=C3',
#  'O=C(CC1=O)N(CC2=CNC3=C2C=CC=C3)C(N1CC4=CNC5=CC=CC=C54)=O',
#  'CCCOCC1=CNC2=CC=CC=C21',
#  'O=C(C(C=CC=C1)=C1C2=O)N2CCCN3N=NC(COCC4=CNC5=C4C=CC=C5)=C3',
#  'C12=CC=CC=C1C(CN3C(C4=CC=CC=C4)N=CC3)=CN2',
#  'S=C(N1CCCC1)SCC2=CNC3=CC=CC=C32',
#  'O=C(C=C1C)NC(N1CC2=CNC3=CC=CC=C32)=S',
#  'O=C(C)N(C1=C2C=CC=C1)C=C2CN3N=NC(CN4C=C(COCC)C5=C4C=CC=C5)=C3',
#  'ClC1=C(Cl)N(C=N1)CC2=CNC3=CC=CC=C32',
#  'O=C(C=C1)NC(N1CC2=CNC3=CC=CC=C32)=O',
#  'O=C1C2=C(C=CC=C2)C(N1CC3=CNC4=CC=CC=C43)=O',
#  'OCC1=CN(C(C)=O)C2=CC=CC=C21',
#  'C12=CC=CC=C1C(CC3=CNC4=C3C=CC=C4)=CN2',
#  'S=C1N(CC2=CNC3=CC=CC=C32)C(C=CC=C4)=C4O1',
#  'O=C(C(C=CC=C1)=C1C2=O)N2CCCCCN3N=NC(COCC4=CNC5=C4C=CC=C5)=C3',
#  'CCCCCOCC1=CNC2=CC=CC=C21',
#  'O=C(C=C1C)N(CC2=CNC3=C2C=CC=C3)C(N1CC4=CNC5=CC=CC=C54)=O',
#  '[N-]=[N+]=NCC1=C(CN2N=NC(COCC3=CNC4=C3C=CC=C4)=C2)C=CC=C1',
#  'O=C(C(C)=C1)N(CC2=CNC3=C2C=CC=C3)C(N1CC4=CNC5=CC=CC=C54)=O',
#  'C12=CC=CC=C1NC=C2COCC3=CN(CCCCCCCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3',
#  'C12=CC=CC=C1NC=C2COCC3=CN(CCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3',
#  '[N-]=[N+]=NCC1=CC(CN=[N+]=[N-])=CC(CN2N=NC(COCC3=CNC4=C3C=CC=C4)=C2)=C1',
#  'C12=CC=CC=C1C(CN3C(C=CC=C4)=C4N=C3)=CN2',
#  'O=C(C=C1)NC(N1CC2=CNC3=CC=CC=C32)=S',
#  'CC(C)CCOCC1=CNC2=CC=CC=C21',
#  'O=C1C2=C(C=CC=C2)C(N1CC3=CN(C(C)=C)C4=CC=CC=C43)=O',
#  'S=C1N(CC2=CNC3=CC=CC=C32)C(C=CC=C4)=C4S1',
#  'CN(C)CC1=CN(C2=C1C=CC=C2)CC3=CNC4=CC=CC=C43',
#  'C12=CC=CC=C1NC=C2COCC3=CN(CCCCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3']

# %%
initial = initial[4:]

# %%
initial
# Out:
# ['CC(C)OCC1=CNC2=CC=CC=C21',
#  'O=C(C)OCC1=CN(C(C)=O)C2=CC=CC=C21',
#  '[N-]=[N+]=NCC1=CC=C(CN2N=NC(COCC3=CNC4=C3C=CC=C4)=C2)C=C1',
#  'CCCCOCC1=CNC2=CC=CC=C21',
#  'CCC1=NC=CN1CC2=CNC3=CC=CC=C32',
#  'CCOCC1=CNC2=CC=CC=C21',
#  'O=C(C(C=CC=C1)=C1C2=O)N2CCCCCCCCN3N=NC(COCC4=CNC5=C4C=CC=C5)=C3',
#  'C12=CC=CC=C1C(CN3C=CN=C3)=CN2',
#  'C12=CC=CC=C1NC=C2COCC3=CN(CCCCCCCCCCCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3',
#  'CCC1=NC(C)=CN1CC2=CNC3=CC=CC=C32',
#  'CC1=NC=CN1CC2=CNC3=CC=CC=C32',
#  'O=C(C(C=CC=C1)=C1C2=O)N2CCCCCCCCCCCCN3N=NC(COCC4=CNC5=C4C=CC=C5)=C3',
#  'O=C(C=C1)N(CC2=CNC3=C2C=CC=C3)C(N1CC4=CNC5=CC=CC=C54)=O',
#  'COCC1=CNC2=CC=CC=C21',
#  'CC(C)C1=NC=CN1CC2=CNC3=CC=CC=C32',
#  'O=C(C)N(C1=C2C=CC=C1)C=C2CN3N=NC(COCC4=CNC5=C4C=CC=C5)=C3',
#  'O=C(CC1=O)N(CC2=CNC3=C2C=CC=C3)C(N1CC4=CNC5=CC=CC=C54)=O',
#  'CCCOCC1=CNC2=CC=CC=C21',
#  'O=C(C(C=CC=C1)=C1C2=O)N2CCCN3N=NC(COCC4=CNC5=C4C=CC=C5)=C3',
#  'C12=CC=CC=C1C(CN3C(C4=CC=CC=C4)N=CC3)=CN2',
#  'S=C(N1CCCC1)SCC2=CNC3=CC=CC=C32',
#  'O=C(C=C1C)NC(N1CC2=CNC3=CC=CC=C32)=S',
#  'O=C(C)N(C1=C2C=CC=C1)C=C2CN3N=NC(CN4C=C(COCC)C5=C4C=CC=C5)=C3',
#  'ClC1=C(Cl)N(C=N1)CC2=CNC3=CC=CC=C32',
#  'O=C(C=C1)NC(N1CC2=CNC3=CC=CC=C32)=O',
#  'O=C1C2=C(C=CC=C2)C(N1CC3=CNC4=CC=CC=C43)=O',
#  'OCC1=CN(C(C)=O)C2=CC=CC=C21',
#  'C12=CC=CC=C1C(CC3=CNC4=C3C=CC=C4)=CN2',
#  'S=C1N(CC2=CNC3=CC=CC=C32)C(C=CC=C4)=C4O1',
#  'O=C(C(C=CC=C1)=C1C2=O)N2CCCCCN3N=NC(COCC4=CNC5=C4C=CC=C5)=C3',
#  'CCCCCOCC1=CNC2=CC=CC=C21',
#  'O=C(C=C1C)N(CC2=CNC3=C2C=CC=C3)C(N1CC4=CNC5=CC=CC=C54)=O',
#  '[N-]=[N+]=NCC1=C(CN2N=NC(COCC3=CNC4=C3C=CC=C4)=C2)C=CC=C1',
#  'O=C(C(C)=C1)N(CC2=CNC3=C2C=CC=C3)C(N1CC4=CNC5=CC=CC=C54)=O',
#  'C12=CC=CC=C1NC=C2COCC3=CN(CCCCCCCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3',
#  'C12=CC=CC=C1NC=C2COCC3=CN(CCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3',
#  '[N-]=[N+]=NCC1=CC(CN=[N+]=[N-])=CC(CN2N=NC(COCC3=CNC4=C3C=CC=C4)=C2)=C1',
#  'C12=CC=CC=C1C(CN3C(C=CC=C4)=C4N=C3)=CN2',
#  'O=C(C=C1)NC(N1CC2=CNC3=CC=CC=C32)=S',
#  'CC(C)CCOCC1=CNC2=CC=CC=C21',
#  'O=C1C2=C(C=CC=C2)C(N1CC3=CN(C(C)=C)C4=CC=CC=C43)=O',
#  'S=C1N(CC2=CNC3=CC=CC=C32)C(C=CC=C4)=C4S1',
#  'CN(C)CC1=CN(C2=C1C=CC=C2)CC3=CNC4=CC=CC=C43',
#  'C12=CC=CC=C1NC=C2COCC3=CN(CCCCCN4N=NC(COCC5=CNC6=C5C=CC=C6)=C4)N=N3']

# %%
generated_smiles = pd.read_excel(File_to_work_with)

# %%
generated_smiles = generated_smiles['new_SMILES']

# %%
generated_smiles
# Out:
# 0                            C1=CN(Cc2c[nH]c3ccccc23)CN1
# 1                      C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12
# 2                                 C=C1C=C(C)NCC2C=CC2CN1
# 3                          C=C1CN(Cc2c[nH]c3ccccc23)C=N1
# 4                                Cc1ncc2n1CC1=CC=CC1CNC2
#                              ...
# 886          CC(=O)CN1C=CCCN=NN(Cc2ccccc2CN=[N+]=[N-])C1
# 887    C=CC=C1C2=CC(=CC2C(C)=O)Cn2cc(nn2)COCc2c[nH]c3...
# 888              CC(=O)N1C=C(C)CN(Cc2c[nH]c3ccccc23)C1=O
# 889    COC1C(C=O)=CN(Cc2c[nH]c3ccccc23)CN1Cc1c[nH]c2c...
# 890    CC(=O)NC=C(C)C(=O)N(CCc1c[nH]c2ccccc12)Cc1c[nH...
# Name: new_SMILES, Length: 891, dtype: object

# %% [markdown]
# ## Molecular descriptors to be used

# %%
from rdkit import Chem
from mordred import Calculator, descriptors, Lipinski
import mordred

# %%
descriptor1_initials = []
descriptor1_generated = []

descriptor2_initials = []
descriptor2_generated = []

descriptor3_initials = []
descriptor3_generated = []

# %%
mol_objs_ini = [Chem.MolFromSmiles(smi) for smi in initial]
mol_objs_gen = [Chem.MolFromSmiles(smi) for smi in generated_smiles]

# %%
calc = Calculator(descriptors, ignore_3D=True)
molecular_descriptors_initials = calc.pandas(mol_objs_ini)
molecular_descriptors_generated = calc.pandas(mol_objs_gen)
# Out:
#  82%|███████████████████████████████████████████████████████████████████               | 36/44 [00:01<00:00, 39.99it/s]
# C:\Users\aleks\anaconda3\envs\cheminf_gpu\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 44/44 [00:01<00:00, 23.22it/s]
#  21%|████████████████▉                                                               | 188/891 [00:03<00:09, 72.27it/s]
# C:\Users\aleks\anaconda3\envs\cheminf_gpu\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\aleks\anaconda3\envs\cheminf_gpu\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\aleks\anaconda3\envs\cheminf_gpu\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\aleks\anaconda3\envs\cheminf_gpu\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\aleks\anaconda3\envs\cheminf_gpu\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\aleks\anaconda3\envs\cheminf_gpu\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#  24%|██████████████████▉                                                             | 211/891 [00:03<00:07, 91.06it/s]
# C:\Users\aleks\anaconda3\envs\cheminf_gpu\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#  98%|██████████████████████████████████████████████████████████████████████████████  | 870/891 [00:15<00:00, 33.21it/s]
# C:\Users\aleks\anaconda3\envs\cheminf_gpu\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|████████████████████████████████████████████████████████████████████████████████| 891/891 [00:15<00:00, 57.04it/s]

# %%
molecular_descriptors_initials.head()
# Out:
#          ABC      ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  SpDiam_A  \
# 0  10.744501   9.599240      0      0  17.913552  2.396885  4.646145
# 1  13.003721  11.509323      0      0  21.133866  2.469394  4.752589
# 2  21.839430  15.891480      0      0  37.385665  2.398135  4.653197
# 3  11.232828   9.788145      0      0  19.721485  2.395336  4.641797
# 4  13.313708  11.878750      0      0  22.868785  2.423440  4.695349
#
#       SpAD_A   SpMAD_A   LogEE_A  ...      SRW10     TSRW10          MW  \
# 0  17.913552  1.279539  3.567227  ...   9.347577  59.350527  189.115364
# 1  21.133866  1.243169  3.754380  ...   9.663134  63.916621  231.089543
# 2  37.385665  1.335202  4.264252  ...  10.029812  78.709848  373.165108
# 3  19.721485  1.314766  3.624202  ...   9.323044  60.377702  203.131014
# 4  22.868785  1.345223  3.786409  ...   9.676524  65.595282  225.126597
#
#         AMW  WPath  WPol  Zagreb1  Zagreb2  mZagreb1  mZagreb2
# 0  6.521219    313    17     70.0     80.0  4.444444  3.138889
# 1  7.702985    513    24     86.0    100.0  6.416667  3.777778
# 2  7.939683   2626    37    144.0    166.0  6.777778  6.305556
# 3  6.347844    411    18     72.0     82.0  4.083333  3.555556
# 4  7.035206    518    23     90.0    107.0  4.305556  3.833333
#
# [5 rows x 1613 columns]

# %%
molecular_descriptors_generated.head()
# Out:
#          ABC      ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  SpDiam_A  \
# 0  11.939935  10.508466      0      0  20.406058  2.411066  4.670137
# 1  14.267954  12.347922      0      0  23.256957  2.491672  4.839023
# 2  10.077834   8.682236      0      0  15.669156  2.349427  4.672023
# 3  12.756432  11.078863      0      2  21.347908  2.415595  4.675455
# 4  12.008885  10.434582      0      1  19.749492  2.419906  4.696585
#
#       SpAD_A   SpMAD_A   LogEE_A  ...     SRW10     TSRW10          MW  \
# 0  20.406058  1.360404  3.671277  ...  9.507849  62.720976  199.110947
# 1  23.256957  1.292053  3.850818  ...  9.927253  67.578947  241.157898
# 2  15.669156  1.205320  3.509942  ...  9.442166  47.551500  176.131349
# 3  21.347908  1.334244  3.732849  ...  9.597438  64.292559  211.110947
# 4  19.749492  1.316633  3.676523  ...  9.562053  63.060515  201.126597
#
#         AMW  WPath  WPol  Zagreb1  Zagreb2  mZagreb1  mZagreb2
# 0  7.111105    366    18     80.0     94.0  3.194444  3.305556
# 1  6.517781    522    31    100.0    121.0  5.868056  3.888889
# 2  6.073495    233    17     66.0     75.0  4.194444  2.861111
# 3  7.279688    444    20     86.0    101.0  4.055556  3.472222
# 4  6.704220    327    23     82.0     98.0  3.805556  3.250000
#
# [5 rows x 1613 columns]

# %%
def is_morder_missing(x):
    return np.nan if type(x) == mordred.error.Missing or type(x) == mordred.error.Error else x

# %%
molecular_descriptors_initials = molecular_descriptors_initials.applymap(is_morder_missing)
molecular_descriptors_generated = molecular_descriptors_generated.applymap(is_morder_missing)

# %%
simple_preprocessing = True
if simple_preprocessing:
    molecular_descriptors_initials = molecular_descriptors_initials.dropna(axis=1, how='any')
    molecular_descriptors_generated = molecular_descriptors_generated.dropna(axis=1, how='any')

# %%
print(molecular_descriptors_initials.isna().sum().sum())
print(molecular_descriptors_generated.isna().sum().sum())
print(molecular_descriptors_initials.shape)
print(molecular_descriptors_generated.shape)
# Out:
# 0
# 0
# (44, 1433)
# (891, 1226)

# %%
molecular_descriptors_initials = molecular_descriptors_initials.loc[:, (molecular_descriptors_initials != 0).any(axis=0)]
molecular_descriptors_generated = molecular_descriptors_generated.loc[:, (molecular_descriptors_generated != 0).any(axis=0)]

# %%
print(molecular_descriptors_initials.shape)
print(molecular_descriptors_generated.shape)
# Out:
# (44, 1182)
# (891, 1100)

# %% [markdown]
# ### Chosen descriptors:
#
# -> "MW"
#
# -> "Diameter"?
#
# -> "SlogP"
#
# -> "TopoPSA"
#
# -> "WPol" -> the Wiener Polarity Number
#
# -> "nRing" -> ring count
#
# -> "AATS0Z" -> averaged moreau-broto autocorrelation of lag 0 weighted by atomic number

# %%
import matplotlib.pyplot as plt
#from mpl_toolkits.mplot3d import Axes3D

# %%
preserve_only_common_columns = []
for element in list(molecular_descriptors_initials.columns):
    if element in list(molecular_descriptors_generated.columns):
        preserve_only_common_columns.append(element)
    else:
        print("Not found in generated structures : ", element)
# Out:
# Not found in generated structures :  AATS5dv
# Not found in generated structures :  AATS6dv
# Not found in generated structures :  AATS7dv
# Not found in generated structures :  AATS8dv
# Not found in generated structures :  AATS5d
# Not found in generated structures :  AATS6d
# Not found in generated structures :  AATS7d
# Not found in generated structures :  AATS8d
# Not found in generated structures :  AATS5s
# Not found in generated structures :  AATS6s
# Not found in generated structures :  AATS7s
# Not found in generated structures :  AATS8s
# Not found in generated structures :  AATS5Z
# Not found in generated structures :  AATS6Z
# Not found in generated structures :  AATS7Z
# Not found in generated structures :  AATS8Z
# Not found in generated structures :  AATS5m
# Not found in generated structures :  AATS6m
# Not found in generated structures :  AATS7m
# Not found in generated structures :  AATS8m
# Not found in generated structures :  AATS5v
# Not found in generated structures :  AATS6v
# Not found in generated structures :  AATS7v
# Not found in generated structures :  AATS8v
# Not found in generated structures :  AATS5se
# Not found in generated structures :  AATS6se
# Not found in generated structures :  AATS7se
# Not found in generated structures :  AATS8se
# Not found in generated structures :  AATS5pe
# Not found in generated structures :  AATS6pe
# Not found in generated structures :  AATS7pe
# Not found in generated structures :  AATS8pe
# Not found in generated structures :  AATS5are
# Not found in generated structures :  AATS6are
# Not found in generated structures :  AATS7are
# Not found in generated structures :  AATS8are
# Not found in generated structures :  AATS5p
# Not found in generated structures :  AATS6p
# Not found in generated structures :  AATS7p
# Not found in generated structures :  AATS8p
# Not found in generated structures :  AATS5i
# Not found in generated structures :  AATS6i
# Not found in generated structures :  AATS7i
# Not found in generated structures :  AATS8i
# Not found in generated structures :  AATSC5c
# Not found in generated structures :  AATSC6c
# Not found in generated structures :  AATSC7c
# Not found in generated structures :  AATSC8c
# Not found in generated structures :  AATSC5dv
# Not found in generated structures :  AATSC6dv
# Not found in generated structures :  AATSC7dv
# Not found in generated structures :  AATSC8dv
# Not found in generated structures :  AATSC5d
# Not found in generated structures :  AATSC6d
# Not found in generated structures :  AATSC7d
# Not found in generated structures :  AATSC8d
# Not found in generated structures :  AATSC5s
# Not found in generated structures :  AATSC6s
# Not found in generated structures :  AATSC7s
# Not found in generated structures :  AATSC8s
# Not found in generated structures :  AATSC5Z
# Not found in generated structures :  AATSC6Z
# Not found in generated structures :  AATSC7Z
# Not found in generated structures :  AATSC8Z
# Not found in generated structures :  AATSC5m
# Not found in generated structures :  AATSC6m
# Not found in generated structures :  AATSC7m
# Not found in generated structures :  AATSC8m
# Not found in generated structures :  AATSC5v
# Not found in generated structures :  AATSC6v
# Not found in generated structures :  AATSC7v
# Not found in generated structures :  AATSC8v
# Not found in generated structures :  AATSC5se
# Not found in generated structures :  AATSC6se
# Not found in generated structures :  AATSC7se
# Not found in generated structures :  AATSC8se
# Not found in generated structures :  AATSC5pe
# Not found in generated structures :  AATSC6pe
# Not found in generated structures :  AATSC7pe
# Not found in generated structures :  AATSC8pe
# Not found in generated structures :  AATSC5are
# Not found in generated structures :  AATSC6are
# Not found in generated structures :  AATSC7are
# Not found in generated structures :  AATSC8are
# Not found in generated structures :  AATSC5p
# Not found in generated structures :  AATSC6p
# Not found in generated structures :  AATSC7p
# Not found in generated structures :  AATSC8p
# Not found in generated structures :  AATSC5i
# Not found in generated structures :  AATSC6i
# Not found in generated structures :  AATSC7i
# Not found in generated structures :  AATSC8i
# Not found in generated structures :  MATS5c
# Not found in generated structures :  MATS6c
# Not found in generated structures :  MATS7c
# Not found in generated structures :  MATS8c
# Not found in generated structures :  MATS5dv
# Not found in generated structures :  MATS6dv
# Not found in generated structures :  MATS7dv
# Not found in generated structures :  MATS8dv
# Not found in generated structures :  MATS5d
# Not found in generated structures :  MATS6d
# Not found in generated structures :  MATS7d
# Not found in generated structures :  MATS8d
# Not found in generated structures :  MATS5s
# Not found in generated structures :  MATS6s
# Not found in generated structures :  MATS7s
# Not found in generated structures :  MATS8s
# Not found in generated structures :  MATS5Z
# Not found in generated structures :  MATS6Z
# Not found in generated structures :  MATS7Z
# Not found in generated structures :  MATS8Z
# Not found in generated structures :  MATS5m
# Not found in generated structures :  MATS6m
# Not found in generated structures :  MATS7m
# Not found in generated structures :  MATS8m
# Not found in generated structures :  MATS5v
# Not found in generated structures :  MATS6v
# Not found in generated structures :  MATS7v
# Not found in generated structures :  MATS8v
# Not found in generated structures :  MATS5se
# Not found in generated structures :  MATS6se
# Not found in generated structures :  MATS7se
# Not found in generated structures :  MATS8se
# Not found in generated structures :  MATS5pe
# Not found in generated structures :  MATS6pe
# Not found in generated structures :  MATS7pe
# Not found in generated structures :  MATS8pe
# Not found in generated structures :  MATS5are
# Not found in generated structures :  MATS6are
# Not found in generated structures :  MATS7are
# Not found in generated structures :  MATS8are
# Not found in generated structures :  MATS5p
# Not found in generated structures :  MATS6p
# Not found in generated structures :  MATS7p
# Not found in generated structures :  MATS8p
# Not found in generated structures :  MATS5i
# Not found in generated structures :  MATS6i
# Not found in generated structures :  MATS7i
# Not found in generated structures :  MATS8i
# Not found in generated structures :  GATS5c
# Not found in generated structures :  GATS6c
# Not found in generated structures :  GATS7c
# Not found in generated structures :  GATS8c
# Not found in generated structures :  GATS5dv
# Not found in generated structures :  GATS6dv
# Not found in generated structures :  GATS7dv
# Not found in generated structures :  GATS8dv
# Not found in generated structures :  GATS5d
# Not found in generated structures :  GATS6d
# Not found in generated structures :  GATS7d
# Not found in generated structures :  GATS8d
# Not found in generated structures :  GATS5s
# Not found in generated structures :  GATS6s
# Not found in generated structures :  GATS7s
# Not found in generated structures :  GATS8s
# Not found in generated structures :  GATS5Z
# Not found in generated structures :  GATS6Z
# Not found in generated structures :  GATS7Z
# Not found in generated structures :  GATS8Z
# Not found in generated structures :  GATS5m
# Not found in generated structures :  GATS6m
# Not found in generated structures :  GATS7m
# Not found in generated structures :  GATS8m
# Not found in generated structures :  GATS5v
# Not found in generated structures :  GATS6v
# Not found in generated structures :  GATS7v
# Not found in generated structures :  GATS8v
# Not found in generated structures :  GATS5se
# Not found in generated structures :  GATS6se
# Not found in generated structures :  GATS7se
# Not found in generated structures :  GATS8se
# Not found in generated structures :  GATS5pe
# Not found in generated structures :  GATS6pe
# Not found in generated structures :  GATS7pe
# Not found in generated structures :  GATS8pe
# Not found in generated structures :  GATS5are
# Not found in generated structures :  GATS6are
# Not found in generated structures :  GATS7are
# Not found in generated structures :  GATS8are
# Not found in generated structures :  GATS5p
# Not found in generated structures :  GATS6p
# Not found in generated structures :  GATS7p
# Not found in generated structures :  GATS8p
# Not found in generated structures :  GATS5i
# Not found in generated structures :  GATS6i
# Not found in generated structures :  GATS7i
# Not found in generated structures :  GATS8i
# Not found in generated structures :  AXp-4d
# Not found in generated structures :  AXp-5d
# Not found in generated structures :  AXp-6d
# Not found in generated structures :  AXp-7d
# Not found in generated structures :  AXp-4dv
# Not found in generated structures :  AXp-5dv
# Not found in generated structures :  AXp-6dv
# Not found in generated structures :  AXp-7dv
# Not found in generated structures :  MAXssCH2
# Not found in generated structures :  MAXaaCH
# Not found in generated structures :  MAXaasC
# Not found in generated structures :  MAXaaaC
# Not found in generated structures :  MINssCH2
# Not found in generated structures :  MINaaCH
# Not found in generated structures :  MINaasC
# Not found in generated structures :  MINaaaC
# Not found in generated structures :  MDEC-22
# Not found in generated structures :  MDEC-23
# Not found in generated structures :  MDEC-33

# %%
len(preserve_only_common_columns)
# Out:
# 975

# %%
print(preserve_only_common_columns)
# Out:
# ['ABC', 'ABCGG', 'nBase', 'SpAbs_A', 'SpMax_A', 'SpDiam_A', 'SpAD_A', 'SpMAD_A', 'LogEE_A', 'VE1_A', 'VE2_A', 'VE3_A', 'VR1_A', 'VR2_A', 'VR3_A', 'nAromAtom', 'nAromBond', 'nAtom', 'nHeavyAtom', 'nHetero', 'nH', 'nC', 'nN', 'nO', 'nS', 'nCl', 'nX', 'ATS0dv', 'ATS1dv', 'ATS2dv', 'ATS3dv', 'ATS4dv', 'ATS5dv', 'ATS6dv', 'ATS7dv', 'ATS8dv', 'ATS0d', 'ATS1d', 'ATS2d', 'ATS3d', 'ATS4d', 'ATS5d', 'ATS6d', 'ATS7d', 'ATS8d', 'ATS0s', 'ATS1s', 'ATS2s', 'ATS3s', 'ATS4s', 'ATS5s', 'ATS6s', 'ATS7s', 'ATS8s', 'ATS0Z', 'ATS1Z', 'ATS2Z', 'ATS3Z', 'ATS4Z', 'ATS5Z', 'ATS6Z', 'ATS7Z', 'ATS8Z', 'ATS0m', 'ATS1m', 'ATS2m', 'ATS3m', 'ATS4m', 'ATS5m', 'ATS6m', 'ATS7m', 'ATS8m', 'ATS0v', 'ATS1v', 'ATS2v', 'ATS3v', 'ATS4v', 'ATS5v', 'ATS6v', 'ATS7v', 'ATS8v', 'ATS0se', 'ATS1se', 'ATS2se', 'ATS3se', 'ATS4se', 'ATS5se', 'ATS6se', 'ATS7se', 'ATS8se', 'ATS0pe', 'ATS1pe', 'ATS2pe', 'ATS3pe', 'ATS4pe', 'ATS5pe', 'ATS6pe', 'ATS7pe', 'ATS8pe', 'ATS0are', 'ATS1are', 'ATS2are', 'ATS3are', 'ATS4are', 'ATS5are', 'ATS6are', 'ATS7are', 'ATS8are', 'ATS0p', 'ATS1p', 'ATS2p', 'ATS3p', 'ATS4p', 'ATS5p', 'ATS6p', 'ATS7p', 'ATS8p', 'ATS0i', 'ATS1i', 'ATS2i', 'ATS3i', 'ATS4i', 'ATS5i', 'ATS6i', 'ATS7i', 'ATS8i', 'AATS0dv', 'AATS1dv', 'AATS2dv', 'AATS3dv', 'AATS4dv', 'AATS0d', 'AATS1d', 'AATS2d', 'AATS3d', 'AATS4d', 'AATS0s', 'AATS1s', 'AATS2s', 'AATS3s', 'AATS4s', 'AATS0Z', 'AATS1Z', 'AATS2Z', 'AATS3Z', 'AATS4Z', 'AATS0m', 'AATS1m', 'AATS2m', 'AATS3m', 'AATS4m', 'AATS0v', 'AATS1v', 'AATS2v', 'AATS3v', 'AATS4v', 'AATS0se', 'AATS1se', 'AATS2se', 'AATS3se', 'AATS4se', 'AATS0pe', 'AATS1pe', 'AATS2pe', 'AATS3pe', 'AATS4pe', 'AATS0are', 'AATS1are', 'AATS2are', 'AATS3are', 'AATS4are', 'AATS0p', 'AATS1p', 'AATS2p', 'AATS3p', 'AATS4p', 'AATS0i', 'AATS1i', 'AATS2i', 'AATS3i', 'AATS4i', 'ATSC0c', 'ATSC1c', 'ATSC2c', 'ATSC3c', 'ATSC4c', 'ATSC5c', 'ATSC6c', 'ATSC7c', 'ATSC8c', 'ATSC0dv', 'ATSC1dv', 'ATSC2dv', 'ATSC3dv', 'ATSC4dv', 'ATSC5dv', 'ATSC6dv', 'ATSC7dv', 'ATSC8dv', 'ATSC0d', 'ATSC1d', 'ATSC2d', 'ATSC3d', 'ATSC4d', 'ATSC5d', 'ATSC6d', 'ATSC7d', 'ATSC8d', 'ATSC0s', 'ATSC1s', 'ATSC2s', 'ATSC3s', 'ATSC4s', 'ATSC5s', 'ATSC6s', 'ATSC7s', 'ATSC8s', 'ATSC0Z', 'ATSC1Z', 'ATSC2Z', 'ATSC3Z', 'ATSC4Z', 'ATSC5Z', 'ATSC6Z', 'ATSC7Z', 'ATSC8Z', 'ATSC0m', 'ATSC1m', 'ATSC2m', 'ATSC3m', 'ATSC4m', 'ATSC5m', 'ATSC6m', 'ATSC7m', 'ATSC8m', 'ATSC0v', 'ATSC1v', 'ATSC2v', 'ATSC3v', 'ATSC4v', 'ATSC5v', 'ATSC6v', 'ATSC7v', 'ATSC8v', 'ATSC0se', 'ATSC1se', 'ATSC2se', 'ATSC3se', 'ATSC4se', 'ATSC5se', 'ATSC6se', 'ATSC7se', 'ATSC8se', 'ATSC0pe', 'ATSC1pe', 'ATSC2pe', 'ATSC3pe', 'ATSC4pe', 'ATSC5pe', 'ATSC6pe', 'ATSC7pe', 'ATSC8pe', 'ATSC0are', 'ATSC1are', 'ATSC2are', 'ATSC3are', 'ATSC4are', 'ATSC5are', 'ATSC6are', 'ATSC7are', 'ATSC8are', 'ATSC0p', 'ATSC1p', 'ATSC2p', 'ATSC3p', 'ATSC4p', 'ATSC5p', 'ATSC6p', 'ATSC7p', 'ATSC8p', 'ATSC0i', 'ATSC1i', 'ATSC2i', 'ATSC3i', 'ATSC4i', 'ATSC5i', 'ATSC6i', 'ATSC7i', 'ATSC8i', 'AATSC0c', 'AATSC1c', 'AATSC2c', 'AATSC3c', 'AATSC4c', 'AATSC0dv', 'AATSC1dv', 'AATSC2dv', 'AATSC3dv', 'AATSC4dv', 'AATSC0d', 'AATSC1d', 'AATSC2d', 'AATSC3d', 'AATSC4d', 'AATSC0s', 'AATSC1s', 'AATSC2s', 'AATSC3s', 'AATSC4s', 'AATSC0Z', 'AATSC1Z', 'AATSC2Z', 'AATSC3Z', 'AATSC4Z', 'AATSC0m', 'AATSC1m', 'AATSC2m', 'AATSC3m', 'AATSC4m', 'AATSC0v', 'AATSC1v', 'AATSC2v', 'AATSC3v', 'AATSC4v', 'AATSC0se', 'AATSC1se', 'AATSC2se', 'AATSC3se', 'AATSC4se', 'AATSC0pe', 'AATSC1pe', 'AATSC2pe', 'AATSC3pe', 'AATSC4pe', 'AATSC0are', 'AATSC1are', 'AATSC2are', 'AATSC3are', 'AATSC4are', 'AATSC0p', 'AATSC1p', 'AATSC2p', 'AATSC3p', 'AATSC4p', 'AATSC0i', 'AATSC1i', 'AATSC2i', 'AATSC3i', 'AATSC4i', 'MATS1c', 'MATS2c', 'MATS3c', 'MATS4c', 'MATS1dv', 'MATS2dv', 'MATS3dv', 'MATS4dv', 'MATS1d', 'MATS2d', 'MATS3d', 'MATS4d', 'MATS1s', 'MATS2s', 'MATS3s', 'MATS4s', 'MATS1Z', 'MATS2Z', 'MATS3Z', 'MATS4Z', 'MATS1m', 'MATS2m', 'MATS3m', 'MATS4m', 'MATS1v', 'MATS2v', 'MATS3v', 'MATS4v', 'MATS1se', 'MATS2se', 'MATS3se', 'MATS4se', 'MATS1pe', 'MATS2pe', 'MATS3pe', 'MATS4pe', 'MATS1are', 'MATS2are', 'MATS3are', 'MATS4are', 'MATS1p',  ...

# %%
x1 = 'MW' #GATS3c
x2 = 'TopoPSA' #WPol
x3 = 'nRing' #AATS0Z

# %%
descriptor1 = 'GATS3c'#str(input('Please input your first descriptor : '))
descriptor2 = 'WPol'#str(input('Please input your second descriptor : '))
descriptor3 = 'AATS0Z'#str(input('Please input your third descriptor : '))

# %%
whole_set_descriptor1 = molecular_descriptors_initials[descriptor1].append(molecular_descriptors_generated[descriptor1])
whole_set_descriptor2 = molecular_descriptors_initials[descriptor2].append(molecular_descriptors_generated[descriptor2])
whole_set_descriptor3 = molecular_descriptors_initials[descriptor3].append(molecular_descriptors_generated[descriptor3])
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21280\1232241802.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   whole_set_descriptor1 = molecular_descriptors_initials[descriptor1].append(molecular_descriptors_generated[descriptor1])
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21280\1232241802.py:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   whole_set_descriptor2 = molecular_descriptors_initials[descriptor2].append(molecular_descriptors_generated[descriptor2])
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21280\1232241802.py:3: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   whole_set_descriptor3 = molecular_descriptors_initials[descriptor3].append(molecular_descriptors_generated[descriptor3])

# %%
print(len(whole_set_descriptor1))
print(len(whole_set_descriptor2))
len(whole_set_descriptor3)
# Out:
# 935
# 935
# 935

# %%
print(whole_set_descriptor1.min(), whole_set_descriptor1.max())
print(whole_set_descriptor2.min(), whole_set_descriptor2.max())
print(whole_set_descriptor3.min(), whole_set_descriptor3.max())
# Out:
# 0.46032212977293835 2.248105350577465
# 1 72
# 14.258064516129032 56.52173913043478

# %%
fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(projection='3d')

ax.scatter(molecular_descriptors_initials[descriptor1], molecular_descriptors_initials[descriptor2], molecular_descriptors_initials[descriptor3], marker='^')
ax.scatter(molecular_descriptors_generated[descriptor1], molecular_descriptors_generated[descriptor2], molecular_descriptors_generated[descriptor3], marker='o')
ax.legend(['Initials', 'Generated'])
ax.set_title('Chemical space of initial indoles and generated structures')
ax.set_xlabel(descriptor1)
ax.set_ylabel(descriptor2)
ax.set_zlabel(descriptor3)
plt.xlim([whole_set_descriptor1.min(), whole_set_descriptor1.max()])
plt.ylim([whole_set_descriptor2.min(), whole_set_descriptor2.max()])
ax.set_zlim([whole_set_descriptor3.min(), whole_set_descriptor3.max()])
plt.show()

# %%
#%matplotlib
# %matplotlib widget
#%matplotlib notebook
fig2 = plt.figure(figsize=(10, 10))
ax = fig2.add_subplot(projection='3d')

ax.scatter(molecular_descriptors_initials[descriptor1], molecular_descriptors_initials[descriptor2], molecular_descriptors_initials[descriptor3], marker='^')
ax.scatter(molecular_descriptors_generated[descriptor1], molecular_descriptors_generated[descriptor2], molecular_descriptors_generated[descriptor3], marker='o')
ax.legend(['Initials', 'Generated'])
ax.set_title('Chemical space of initial indoles and generated structures')
ax.set_xlabel(descriptor1)
ax.set_ylabel(descriptor2)
ax.set_zlabel(descriptor3)
plt.xlim([whole_set_descriptor1.min(), whole_set_descriptor1.max()])
plt.ylim([whole_set_descriptor2.min(), whole_set_descriptor2.max()])
ax.set_zlim([whole_set_descriptor3.min(), whole_set_descriptor3.max()])

#plt.show()
plt.ion()
plt.savefig("Indole_chemical_space.svg")
#plt.savefig("Indole_chemical_space.pdf")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
## creation of 3D graphs in *svg format for each azimuth
create_pictures_to_movie = 0
if create_pictures_to_movie == 1:
    for ii in range(0,360,1):
        ax.view_init(elev=10., azim=ii)
        plt.savefig("chemical_space/movie%d.svg" % ii)
else:
    pass

# %% [markdown]
# ## Save used descriptors to excel file

# %%
initial_strcutures = pd.DataFrame(data=molecular_descriptors_initials[descriptor1], columns=[descriptor1])

# %%
initial_strcutures.head()
# Out:
#      GATS3c
# 0  1.311669
# 1  1.244521
# 2  0.875358
# 3  0.938566
# 4  1.049751

# %%
initial_strcutures[descriptor2] = molecular_descriptors_initials[descriptor2]
initial_strcutures[descriptor3] = molecular_descriptors_initials[descriptor3]
initial_strcutures['smiles'] = initial

# %%
initial_strcutures.head()
# Out:
#      GATS3c  WPol     AATS0Z  \
# 0  1.311669    17  19.310345
# 1  1.244521    24  24.066667
# 2  0.875358    37  24.382979
# 3  0.938566    18  18.687500
# 4  1.049751    23  20.812500
#
#                                               smiles
# 0                           CC(C)OCC1=CNC2=CC=CC=C21
# 1                  O=C(C)OCC1=CN(C(C)=O)C2=CC=CC=C21
# 2  [N-]=[N+]=NCC1=CC=C(CN2N=NC(COCC3=CNC4=C3C=CC=...
# 3                            CCCCOCC1=CNC2=CC=CC=C21
# 4                      CCC1=NC=CN1CC2=CNC3=CC=CC=C32

# %%
initial_strcutures.to_excel('../Data/Initial_indoles.xlsx')

# %%
generated_strcutures = pd.DataFrame(data=molecular_descriptors_generated[descriptor1], columns=[descriptor1])

# %%
generated_strcutures[descriptor2] = molecular_descriptors_generated[descriptor2]
generated_strcutures[descriptor3] = molecular_descriptors_generated[descriptor3]
generated_strcutures['smiles'] = generated_smiles

# %%
generated_strcutures.head()
# Out:
#      GATS3c  WPol     AATS0Z                             smiles
# 0  0.786884    18  21.142857        C1=CN(Cc2c[nH]c3ccccc23)CN1
# 1  1.142041    31  19.081081  C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12
# 2  1.446019    17  17.586207             C=C1C=C(C)NCC2C=CC2CN1
# 3  0.837177    20  21.655172      C=C1CN(Cc2c[nH]c3ccccc23)C=N1
# 4  1.151340    23  19.800000            Cc1ncc2n1CC1=CC=CC1CNC2

# %%
generated_strcutures.to_excel('../Data/generated_indoles.xlsx')

# %% [markdown]
# ## Choose the generated structures that are the most similar to the initial structure

# %%
def takeClosest(descriptor_1, descriptor_1_collection, descriptor_2, descriptor_2_collection, descriptor_3, descriptor_3_collection):
    average_picked = (descriptor_1+descriptor_2+descriptor_3)/3
    val = range(len(generated_strcutures[descriptor1]))
    dfc = pd.DataFrame(data=val, columns=['Number'])
    val_ = []
    for i in range(len(descriptor_1_collection)):
        average_ = (descriptor_1_collection[i]+descriptor_2_collection[i]+descriptor_3_collection[i])/3
        val_.append(average_)
    dfc['Average'] = val_
    
    closest_val = min(dfc['Average'], key=lambda x:abs(x-average_picked))
    
    closest_value_df =  dfc.loc[(dfc['Average'] == closest_val)]
    
    dfc = dfc.loc[dfc['Average'] != closest_val]
    
    closest_val_ = min(dfc['Average'], key=lambda x:abs(x-average_picked))
    
    closest_value_df_ =  dfc.loc[(dfc['Average'] == closest_val_)]
    
    dfc = dfc.loc[dfc['Average'] != closest_val_]
    
    closest_val__ = min(dfc['Average'], key=lambda x:abs(x-average_picked))
    
    closest_value_df__ =  dfc.loc[(dfc['Average'] == closest_val__)]
    
    closest_value_df_combined = pd.concat([closest_value_df, closest_value_df_, closest_value_df__], ignore_index=True)
    
    return closest_value_df_combined

# %%
selected_structure_ = int(input("Please write down the integer from 0 to 44 down here: ")) #29
descriptor_1_picked = molecular_descriptors_initials[descriptor1][selected_structure_]
descriptor_2_picked = molecular_descriptors_initials[descriptor2][selected_structure_]
descriptor_3_picked = molecular_descriptors_initials[descriptor3][selected_structure_]
# Out:
# Please write down the integer from 0 to 44 down here: 29

# %%
numbers_of_structures = takeClosest(descriptor_1_picked, molecular_descriptors_generated[descriptor1],
                                   descriptor_2_picked, molecular_descriptors_generated[descriptor2],
                                   descriptor_3_picked, molecular_descriptors_generated[descriptor3])

# %%
numbers_of_structures
# Out:
#    Number    Average
# 0      87  24.494861
# 1     721  24.487042
# 2     113  24.510389

# %%
numbers_of_structures["Number"][0]
# Out:
# 87

# %%
picked_average = (descriptor_1_picked+descriptor_2_picked+descriptor_3_picked)/3
picked_average
# Out:
# 24.492620859909877

# %%
descriptor_1_cloeset = molecular_descriptors_generated[descriptor1][numbers_of_structures['Number'][0:]]
descriptor_2_closest = molecular_descriptors_generated[descriptor2][numbers_of_structures['Number'][0:]]
descriptor_3_closed = molecular_descriptors_generated[descriptor3][numbers_of_structures['Number'][0:]]

# %%
print('PICKED descriptors:')
print(descriptor_1_picked)
print(descriptor_2_picked)
print(descriptor_3_picked)
print('Closest descriptors:')
print(descriptor_1_cloeset)
print(descriptor_2_closest)
print(descriptor_3_closed)
# Out:
# PICKED descriptors:
# 0.9951039590399727
# 49
# 23.482758620689655
# Closest descriptors:
# 87     1.033604
# 721    1.127793
# 113    1.060580
# Name: GATS3c, dtype: float64
# 87     49
# 721    49
# 113    50
# Name: WPol, dtype: int64
# 87     23.450980
# 721    23.333333
# 113    22.470588
# Name: AATS0Z, dtype: float64

# %%
picked_structure = initial_strcutures.loc[(initial_strcutures[descriptor1] == descriptor_1_picked) & (initial_strcutures[descriptor2] == descriptor_2_picked) & (initial_strcutures[descriptor3] == descriptor_3_picked)]

# %%
picked_structure
# Out:
#       GATS3c  WPol     AATS0Z  \
# 29  0.995104    49  23.482759
#
#                                                smiles
# 29  O=C(C(C=CC=C1)=C1C2=O)N2CCCCCN3N=NC(COCC4=CNC5...

# %%
Chem.MolFromSmiles(picked_structure['smiles'][selected_structure_])

# %%
descriptor_1_cloeset[numbers_of_structures["Number"][0]]
# Out:
# 1.0336040255052397

# %%
closest_gen_stru = pd.DataFrame()
for ithem in range(len(descriptor_1_cloeset)):
    df_res = generated_strcutures.loc[(generated_strcutures[descriptor1] == descriptor_1_cloeset[numbers_of_structures["Number"][ithem]]) 
                                            & (generated_strcutures[descriptor2] == descriptor_2_closest[numbers_of_structures["Number"][ithem]]) 
                                            & (generated_strcutures[descriptor3] == descriptor_3_closed[numbers_of_structures["Number"][ithem]])]
    closest_gen_stru=closest_gen_stru.append(df_res)
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21280\2947859290.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   closest_gen_stru=closest_gen_stru.append(df_res)
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21280\2947859290.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   closest_gen_stru=closest_gen_stru.append(df_res)
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21280\2947859290.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   closest_gen_stru=closest_gen_stru.append(df_res)

# %%
closest_gen_stru
# Out:
#        GATS3c  WPol     AATS0Z  \
# 87   1.033604    49  23.450980
# 721  1.127793    49  23.333333
# 113  1.060580    50  22.470588
#
#                                                 smiles
# 87   O=C1c2ccccc2C(=O)N1CC=C1C=CC=CC1NCc1c[nH]c2ccc...
# 721  CC(=O)n1c(C)c(Cn2cc(COCc3c[nH]c4ccccc34)nn2)c2...
# 113  CC(=O)N1C=C2CNC=CC(Cc3cc4ccccc4[nH]3)=CNc3ccc2...

# %%
Chem.MolFromSmiles(closest_gen_stru['smiles'][int(numbers_of_structures['Number'][0])])

# %%
Chem.MolFromSmiles(closest_gen_stru['smiles'][int(numbers_of_structures['Number'][1])])

# %%
Chem.MolFromSmiles(closest_gen_stru['smiles'][int(numbers_of_structures['Number'][2])])

# %% [markdown]
# ## Search within a box

# %%
center_of_a_box = [descriptor_1_picked, descriptor_2_picked, descriptor_3_picked]

# %%
size_of_a_box = [descriptor_1_picked/2, descriptor_2_picked/2, descriptor_3_picked/2]

# %%
def create_a_box_to_search_within(center_of_a_box, size_of_a_box):
    chemical_space_descriptor_1 = [center_of_a_box[0]-size_of_a_box[0], center_of_a_box[0]+size_of_a_box[0]]
    chemical_space_descriptor_2 = [center_of_a_box[1]-size_of_a_box[1], center_of_a_box[1]+size_of_a_box[1]]
    chemical_space_descriptor_3 = [center_of_a_box[2]-size_of_a_box[2], center_of_a_box[2]+size_of_a_box[2]]
    return chemical_space_descriptor_1, chemical_space_descriptor_2, chemical_space_descriptor_3

# %%
chemical_space_descriptor_1, chemical_space_descriptor_2, chemical_space_descriptor_3 = create_a_box_to_search_within(center_of_a_box, size_of_a_box)

# %%
chemical_space_descriptor_1
# Out:
# [0.49755197951998636, 1.4926559385599592]

# %%
chemical_space_descriptor_2
# Out:
# [24.5, 73.5]

# %%
chemical_space_descriptor_3
# Out:
# [11.741379310344827, 35.224137931034484]

# %%
selected_structures = generated_strcutures.loc[(generated_strcutures[descriptor1] >= chemical_space_descriptor_1[0]) 
                                               & (generated_strcutures[descriptor1] <= chemical_space_descriptor_1[1]) 
                                               & (generated_strcutures[descriptor2] >= chemical_space_descriptor_2[0]) 
                                               & (generated_strcutures[descriptor2] <= chemical_space_descriptor_2[1]) 
                                               & (generated_strcutures[descriptor3] >= chemical_space_descriptor_3[0]) 
                                               & (generated_strcutures[descriptor3] >= chemical_space_descriptor_3[1])]

# %%
selected_structures
# Out:
#        GATS3c  WPol     AATS0Z                                   smiles
# 291  1.010814    30  35.294118          Sc1[nH]c2ccccc2c1CN1Cc2ccccc2S1
# 423  0.826700    26  45.680000          O=S=C1SCC(=O)N1c1c[nH]c2ccccc12
# 503  0.835297    35  37.393939     S=C1c2ccccc2C(=S)N1Cc1c[nH]c2ccccc12
# 505  1.208492    29  36.750000    Cc1cc(=S)[nH]c(=S)n1Cc1c[nH]c2ccccc12
# 664  0.979403    27  35.294118    c1ccc(N2SC2=[SH]Cc2c[nH]c3ccccc23)cc1
# 699  0.839638    26  36.774194          N=CC1SC=C(S)N1Cc1c[nH]c2ccccc12
# 700  0.932759    36  37.393939  S=C1C=CC=CC=C2C(=S)N1C2c1c[nH]c2ccccc12
# 702  1.189410    29  40.066667    O=C1CC(=S)N(Cc2c[nH]c3ccccc23)C(=S)N1
# 736  1.063085    41  39.315789  C=CC=CC=CSC1(S)c2cccc3c(c[nH]c23)CN1C=S
# 747  0.646761    25  37.419355        CNC=C(Cl)C=C(C=S)c1c[nH]c2ccccc12
# 748  0.756048    25  37.312500       Cc1cccc2c(CCN3CC(Cl)=C3Cl)c[nH]c12
# 841  1.017782    25  37.677419         O=C1NC[SH]=CN1SCc1c[nH]c2ccccc12

# %%
print("Picked initial structure: "+ str(descriptor1) + ' ' + str(descriptor_1_picked), str(descriptor2) + ' ' + str(descriptor_2_picked), str(descriptor3) + ' ' + str(descriptor_3_picked))
# Out:
# Picked initial structure: GATS3c 0.9951039590399727 WPol 49 AATS0Z 23.482758620689655

# %%
mols = [Chem.MolFromSmiles(smi) for smi in selected_structures['smiles']]

# %%
Chem.Draw.MolsToGridImage(mols)
