# %%
import pandas as pd

# %%
excel = pd.read_excel('../Data/new_structures_indole.xlsx')

# %%
excel.head()
# Out:
#    Unnamed: 0            SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0           0     C1[NH1]C=CN1CC2=C[NH1]C3=CC=CC=C32    0              0
# 1           1  CC1(CN2C=C(N=C2CC)C[NH1]C3=C)C=CC=C31    0              0
# 2           2         C12C(CNC(C)=CC([NH1]C1)=C)C=C2    0              0
# 3           3     C=C1CN(C=N1)CC2=C[NH1]C3=CC=CC=C32    0              0
# 4           4      C12C(CN3C(C)=NC=C3C[NH1]C1)=CC=C2    0              0

# %%
excel = excel.drop(columns=['Unnamed: 0'])

# %%
excel.head()
# Out:
#              SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0     C1[NH1]C=CN1CC2=C[NH1]C3=CC=CC=C32    0              0
# 1  CC1(CN2C=C(N=C2CC)C[NH1]C3=C)C=CC=C31    0              0
# 2         C12C(CNC(C)=CC([NH1]C1)=C)C=C2    0              0
# 3     C=C1CN(C=N1)CC2=C[NH1]C3=CC=CC=C32    0              0
# 4      C12C(CN3C(C)=NC=C3C[NH1]C1)=CC=C2    0              0

# %%
excel_1 = excel.copy()

# %%
excel_1.head()
# Out:
#              SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0     C1[NH1]C=CN1CC2=C[NH1]C3=CC=CC=C32    0              0
# 1  CC1(CN2C=C(N=C2CC)C[NH1]C3=C)C=CC=C31    0              0
# 2         C12C(CNC(C)=CC([NH1]C1)=C)C=C2    0              0
# 3     C=C1CN(C=N1)CC2=C[NH1]C3=CC=CC=C32    0              0
# 4      C12C(CN3C(C)=NC=C3C[NH1]C1)=CC=C2    0              0

# %%
excel_1.drop(index=1)
# Out:
#                             SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0                    C1[NH1]C=CN1CC2=C[NH1]C3=CC=CC=C32    0              0
# 2                        C12C(CNC(C)=CC([NH1]C1)=C)C=C2    0              0
# 3                    C=C1CN(C=N1)CC2=C[NH1]C3=CC=CC=C32    0              0
# 4                     C12C(CN3C(C)=NC=C3C[NH1]C1)=CC=C2    0              0
# 5                    C1CCN(CC2=C[NH1]C3=C2C=CC=C3)C=CN1    0              0
# ...                                                 ...  ...            ...
# 1170  O=C(C1=C(C=CC=C1)N)CC=2N=NN(C=2)CC3=CN(C4=CC=C...    0              0
# 1171  O=CC(C)=CN(C(NCC=1C2=CC=CC=C2[NH1]C=1)=O)CC3=C...    0              0
# 1172       O=C(C)N1C=C(C)CN(CC2=C[NH1]C3=C2C=CC=C3)C1=O    0              0
# 1173  O=CC1=CN(CC2=C[NH1]C3=C2C=CC=C3)CN(CC4=C[NH1]C...    0              0
# 1174  O=C(C)NC=C(C)C(=O)N(CC1=C[NH1]C2=C1C=CC=C2)CCC...    0              0
#
# [1174 rows x 3 columns]

# %%
excel_1.head()
# Out:
#              SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0     C1[NH1]C=CN1CC2=C[NH1]C3=CC=CC=C32    0              0
# 1  CC1(CN2C=C(N=C2CC)C[NH1]C3=C)C=CC=C31    0              0
# 2         C12C(CNC(C)=CC([NH1]C1)=C)C=C2    0              0
# 3     C=C1CN(C=N1)CC2=C[NH1]C3=CC=CC=C32    0              0
# 4      C12C(CN3C(C)=NC=C3C[NH1]C1)=CC=C2    0              0

# %%
from rdkit import Chem
from rdkit.DataStructs.cDataStructs import TanimotoSimilarity

# %%
new_smils = []
for smiles in excel['SMILES_From_Tensor_rotation']:
    canon = Chem.MolToSmiles(Chem.MolFromSmiles(smiles), canonical=True, isomericSmiles=False)
    new_smils.append(canon)

# %%
len(new_smils)
# Out:
# 1175

# %%
data = pd.DataFrame(data=new_smils, columns=['new_SMILES'])
drop_duplicates_smi = data.drop_duplicates(subset=['new_SMILES'])
new_file = drop_duplicates_smi
#drop_duplicates_smi = list(set(new_smils))
new_file.head()
# Out:
#                           new_SMILES
# 0        C1=CN(Cc2c[nH]c3ccccc23)CN1
# 1  C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12
# 2             C=C1C=C(C)NCC2C=CC2CN1
# 3      C=C1CN(Cc2c[nH]c3ccccc23)C=N1
# 4            Cc1ncc2n1CC1=CC=CC1CNC2

# %%
len(drop_duplicates_smi)
# Out:
# 928

# %%
new_file['CID'] = 0
new_file['PUBCHEM_SMILES'] = 0
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21860\2792383417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file['CID'] = 0
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21860\2792383417.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file['PUBCHEM_SMILES'] = 0

# %%
read_found_structres = excel_1

# %%
read_found_structres.head()
# Out:
#              SMILES_From_Tensor_rotation  CID PUBCHEM_SMILES
# 0     C1[NH1]C=CN1CC2=C[NH1]C3=CC=CC=C32    0              0
# 1  CC1(CN2C=C(N=C2CC)C[NH1]C3=C)C=CC=C31    0              0
# 2         C12C(CNC(C)=CC([NH1]C1)=C)C=C2    0              0
# 3     C=C1CN(C=N1)CC2=C[NH1]C3=CC=CC=C32    0              0
# 4      C12C(CN3C(C)=NC=C3C[NH1]C1)=CC=C2    0              0

# %%
read_found_structres = read_found_structres.loc[read_found_structres['CID'] > 0]

# %%
read_found_structres.head()
# Out:
#        SMILES_From_Tensor_rotation       CID          PUBCHEM_SMILES
# 8   C1CCN(C2=C(C=CC=C2)[NH1]C)C=C1  68061985  CNC1=CC=CC=C1N2CCCC=C2
# 13                           CCCCl     10899                   CCCCl
# 16                     CC=1CN=CN=1  15300249              CC1=NC=NC1
# 40      CCOCC=1C2=CC=CC=C2[NH1]C=1  12701690   CCOCC1=CNC2=CC=CC=C21
# 43    CCOCC=1C2=C(C=CC=C2)[NH1]C=1  12701690   CCOCC1=CNC2=CC=CC=C21

# %%
read_found_structres = read_found_structres.reset_index()

# %%
read_found_structres.head()
# Out:
#    index     SMILES_From_Tensor_rotation       CID          PUBCHEM_SMILES
# 0      8  C1CCN(C2=C(C=CC=C2)[NH1]C)C=C1  68061985  CNC1=CC=CC=C1N2CCCC=C2
# 1     13                           CCCCl     10899                   CCCCl
# 2     16                     CC=1CN=CN=1  15300249              CC1=NC=NC1
# 3     40      CCOCC=1C2=CC=CC=C2[NH1]C=1  12701690   CCOCC1=CNC2=CC=CC=C21
# 4     43    CCOCC=1C2=C(C=CC=C2)[NH1]C=1  12701690   CCOCC1=CNC2=CC=CC=C21

# %%
for r, m in enumerate(read_found_structres['PUBCHEM_SMILES']):
    fingerprint_ = Chem.RDKFingerprint(Chem.MolFromSmiles(m))
    for i, element in enumerate(new_file['new_SMILES']):
        fingerprint_gen_str = Chem.RDKFingerprint(Chem.MolFromSmiles(element))
        sim = TanimotoSimilarity(fingerprint_, fingerprint_gen_str)
        if sim == 1:
            new_file['PUBCHEM_SMILES'][i] = m
            new_file['CID'][i] = read_found_structres['CID'][r]
        else:
            pass
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21860\2800160880.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file['PUBCHEM_SMILES'][i] = m
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21860\2800160880.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file['CID'][i] = read_found_structres['CID'][r]
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21860\2800160880.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
new_file.head()
# Out:
#                           new_SMILES  CID PUBCHEM_SMILES
# 0        C1=CN(Cc2c[nH]c3ccccc23)CN1    0              0
# 1  C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12    0              0
# 2             C=C1C=C(C)NCC2C=CC2CN1    0              0
# 3      C=C1CN(Cc2c[nH]c3ccccc23)C=N1    0              0
# 4            Cc1ncc2n1CC1=CC=CC1CNC2    0              0

# %% [markdown]
# ## Tanomoto_similarity to initial structures

# %%
smifile = "../Data/Indole_-_cytoprotekcja_NEW_improved_smiles.xlsx"
data = pd.read_excel(smifile)
data = data['SMILES'][:45]

initial_structures_new = list(set(data))
print(len(initial_structures_new))
# Out:
# 44

# %%
for element in initial_structures_new:
    new_file[element] = 0

# %%
new_file = new_file.reset_index()
new_file = new_file.drop(columns=['index'])
new_file
# Out:
#                                             new_SMILES  CID PUBCHEM_SMILES  \
# 0                          C1=CN(Cc2c[nH]c3ccccc23)CN1    0              0
# 1                    C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12    0              0
# 2                               C=C1C=C(C)NCC2C=CC2CN1    0              0
# 3                        C=C1CN(Cc2c[nH]c3ccccc23)C=N1    0              0
# 4                              Cc1ncc2n1CC1=CC=CC1CNC2    0              0
# ..                                                 ...  ...            ...
# 923        CC(=O)CN1C=CCCN=NN(Cc2ccccc2CN=[N+]=[N-])C1    0              0
# 924  C=CC=C1C2=CC(=CC2C(C)=O)Cn2cc(nn2)COCc2c[nH]c3...    0              0
# 925            CC(=O)N1C=C(C)CN(Cc2c[nH]c3ccccc23)C1=O    0              0
# 926  COC1C(C=O)=CN(Cc2c[nH]c3ccccc23)CN1Cc1c[nH]c2c...    0              0
# 927  CC(=O)NC=C(C)C(=O)N(CCc1c[nH]c2ccccc12)Cc1c[nH...    0              0
#
#      CC(C)OCC1=CNC2=CC=CC=C21  O=C(C)OCC1=CN(C(C)=O)C2=CC=CC=C21  \
# ...

# %%
for element in initial_structures_new:
    finger_1 = Chem.RDKFingerprint(Chem.MolFromSmiles(element))
    for i, smi in enumerate(new_file['new_SMILES']):
        finger_2 = Chem.RDKFingerprint(Chem.MolFromSmiles(smi))
        ta_sim = TanimotoSimilarity(finger_1, finger_2)
        new_file[element][i] = ta_sim
        if ta_sim == 1:
            new_file[element][i] = 100
# Out:
# C:\Users\aleks\AppData\Local\Temp\ipykernel_21860\1750637079.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_file[element][i] = ta_sim

# %%
new_file.head()
# Out:
#                           new_SMILES  CID PUBCHEM_SMILES  \
# 0        C1=CN(Cc2c[nH]c3ccccc23)CN1    0              0
# 1  C=C1NCc2cn(c(CC)n2)CC2(C)C=CC=C12    0              0
# 2             C=C1C=C(C)NCC2C=CC2CN1    0              0
# 3      C=C1CN(Cc2c[nH]c3ccccc23)C=N1    0              0
# 4            Cc1ncc2n1CC1=CC=CC1CNC2    0              0
#
#    CC(C)OCC1=CNC2=CC=CC=C21  O=C(C)OCC1=CN(C(C)=O)C2=CC=CC=C21  \
# 0                  0.446228                           0.370541
# 1                  0.170796                           0.270079
# 2                  0.074313                           0.083995
# 3                  0.422680                           0.366703
# 4                  0.160750                           0.227615
#
#    [N-]=[N+]=NCC1=CC=C(CN2N=NC(COCC3=CNC4=C3C=CC=C4)=C2)C=C1  \
# 0                                           0.380471
# 1                                           0.267843
# 2                                           0.104444
# ...

# %%
new_file.columns[3:][0]
# Out:
# 'CC(C)OCC1=CNC2=CC=CC=C21'

# %%
for element in new_file.columns[3:]:
    
    new_file = new_file.drop(new_file[new_file[element] > 99].index)

# %%
new_file.shape
# Out:
# (891, 47)

# %%
new_file.to_excel('../Data/Proposed_structures_with_AI_indole_tanimoto_similarity_.xlsx')
